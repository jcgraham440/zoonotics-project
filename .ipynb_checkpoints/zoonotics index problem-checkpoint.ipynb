# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import sqlalchemy as sql

# %% [markdown]
# US outbreaks file Extraction and Transformation

# %%
outbreaks_file = "Resources/NationalOutbreakPublicDataTool.csv"
outbreaks_df = pd.read_csv(outbreaks_file)
len(outbreaks_df)
# Out:
# 46024

# %%
# Clean up and transform outbreaks data
outbreaks_cols = ["Year", "Month", "State", "Primary Mode", "Etiology", "Animal Type"]
outbreaks_transformed = outbreaks_df[outbreaks_cols].copy()

# %%
outbreaks_transformed.dropna(inplace=True)
outbreaks_transformed.reset_index(drop=True, inplace=True)
outbreaks_transformed.head()
# Out:
#    Year  Month    State    Primary Mode                 Etiology  \
# 0  2009      1     Ohio  Animal Contact  Cryptosporidium unknown
# 1  2009      3  Montana  Animal Contact  Cryptosporidium unknown
# 2  2009      4     Ohio  Animal Contact      Salmonella enterica
# 3  2009      5     Ohio  Animal Contact  Cryptosporidium unknown
# 4  2009      5     Iowa  Animal Contact  Cryptosporidium unknown
#
#       Animal Type
# 0          Cattle
# 1  Sheep or goats
# 2        Pet fish
# 3          Cattle
# 4  Sheep or goats

# %%
outbreaks_transformed.rename(columns={"Year":"year",
                          "Month":'month',
                         "State":'state',
                          "Primary Mode":'mode', 
                           "Etiology":"etiology",
                            "Animal Type" : "animal_type"}, 
                             inplace=True)

outbreaks_transformed.head()
# Out:
#    year  month    state            mode                 etiology  \
# 0  2009      1     Ohio  Animal Contact  Cryptosporidium unknown
# 1  2009      3  Montana  Animal Contact  Cryptosporidium unknown
# 2  2009      4     Ohio  Animal Contact      Salmonella enterica
# 3  2009      5     Ohio  Animal Contact  Cryptosporidium unknown
# 4  2009      5     Iowa  Animal Contact  Cryptosporidium unknown
#
#       animal_type
# 0          Cattle
# 1  Sheep or goats
# 2        Pet fish
# 3          Cattle
# 4  Sheep or goats

# %%
outbreaks_transformed.rename(columns={"Mode": 'mode'},
                          
                             inplace=True)
outbreaks_transformed.head()

# outbreaks_transformed1= outbreaks_transformed.insert(0, 'id')

# outbreaks_transformed1
# Out:
#    year  month    state            mode                 etiology  \
# 0  2009      1     Ohio  Animal Contact  Cryptosporidium unknown
# 1  2009      3  Montana  Animal Contact  Cryptosporidium unknown
# 2  2009      4     Ohio  Animal Contact      Salmonella enterica
# 3  2009      5     Ohio  Animal Contact  Cryptosporidium unknown
# 4  2009      5     Iowa  Animal Contact  Cryptosporidium unknown
#
#       animal_type
# 0          Cattle
# 1  Sheep or goats
# 2        Pet fish
# 3          Cattle
# 4  Sheep or goats

# %%
#df['index_col'] = df.index
#df['index_col'] = df.index


# outbreaks_transformed['id'] = outbreaks

# outbreaks_transformed.head()

outbreaks_transformed['id']= outbreaks_transformed.index

outbreaks_transformed

# %%
#df['index_col'] = df.index


outbreaks_transformed['id'] = outbreaks_transformed.index

outbreaks_transformed.head()
# get a list of columns
cols = list(outbreaks_transformed1)
# move the column to head of list using index, pop and insert
cols.insert(0, cols.pop(cols.index('id')))
cols

# %% [markdown]
# Global outbreaks file extraction and transformation

# %%
#read in file, set the index to the countries, to transform the data
burulicsv = "Resources/Global_Raw_CSV/buruli_ulcer.csv"
buruli_df = pd.read_csv(burulicsv)
buruli_df.set_index("Unnamed: 0", inplace=True)
buruli_df

# %%
#transform the data
buruli_df=buruli_df.T

buruli_df

# %%
#reset the index and clean up disease infection agent
buruli_df=buruli_df.reset_index()
buruli_df["index"] = buruli_df["index"].str.replace("Number of", "")
buruli_df["index"] = buruli_df["index"].str.split(".", n = 1, expand = True)[0]
buruli_df

# %%
buruli_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)

# %%
buruli_df

# %%
buruli_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)

# %%
buruli_df

# %%
buruli_df.columns.names = ['']

# %%
buruli_df

# %%
buruli_df_clean = buruli_df.replace("No data", "NaN")

# %%
buruli_df_clean

# %%
rabiescsv = "Resources/Global_Raw_CSV/rabies.csv"
rabies_df = pd.read_csv(rabiescsv)
rabies_df.set_index("Unnamed: 0", inplace=True)
rabies_df

# %%
rabies_df=rabies_df.T
rabies_df

# %%
rabies_df=rabies_df.reset_index()
rabies_df["index"] = rabies_df["index"].str.replace("Reported number of ", "")
rabies_df["index"] = rabies_df["index"].str.split(".", n = 1, expand = True)[0]
rabies_df

# %%
rabies_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)
rabies_df

# %%
rabies_df.columns.names = ['']
rabies_df

# %%
rabies_df_clean = rabies_df.replace("No data", "NaN")
rabies_df_clean

# %%
gambiensecsv = "Resources/Global_Raw_CSV/tb_gambiense.csv"
gambiense_df = pd.read_csv(gambiensecsv)
gambiense_df.set_index("Unnamed: 0", inplace=True)
gambiense_df

# %%
gambiense_df=gambiense_df.T
gambiense_df

# %%
gambiense_df=gambiense_df.reset_index()
gambiense_df["index"] = gambiense_df["index"].str.replace("Number of ", "").replace(" (T.b. gambiense)", "-Tb gambiense")
gambiense_df["index"] = gambiense_df["index"].str.split(".", n = 1, expand = True)[0]
gambiense_df

# %%
gambiense_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)
gambiense_df

# %%
gambiense_df.columns.names = ['']
gambiense_df

# %%
gambiense_df_clean = gambiense_df.replace("No data", "NaN")
gambiense_df_clean

# %%
rhodesiensecsv = "Resources/Global_Raw_CSV/tb_rhodesiense.csv"
rhodesiense_df = pd.read_csv(rhodesiensecsv)
rhodesiense_df.set_index("Unnamed: 0", inplace=True)
rhodesiense_df

# %%
rhodesiense_df=rhodesiense_df.T

rhodesiense_df

# %%
rhodesiense_df=rhodesiense_df.reset_index()
rhodesiense_df["index"] = rhodesiense_df["index"].str.replace("Number of new reported cases of", "").replace(" (T.b. rhodesiense)", "-Tb rhodesiense")
rhodesiense_df["index"] = rhodesiense_df["index"].str.split(".", n = 1, expand = True)[0]
rhodesiense_df

# %%
rhodesiense_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)
rhodesiense_df

# %%
rhodesiense_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)
rhodesiense_df

# %%
rhodesiense_df.columns.names = ['']
rhodesiense_df

# %%
rhodesiense_df_clean = buruli_df.replace("No data", "NaN")
rhodesiense_df_clean

# %%
global_clean =pd.concat([buruli_df_clean, rabies_df_clean, gambiense_df_clean, rhodesiense_df_clean], sort=False, ignore_index=True)
global_clean
# Out:
#                                    Infectious Disease   Year Angola Australia  \
# 0                  new reported cases of Buruli ulcer   2018    NaN       358
# 1                  new reported cases of Buruli ulcer   2017    NaN       292
# 2                  new reported cases of Buruli ulcer   2016    NaN       186
# 3                  new reported cases of Buruli ulcer   2015    NaN       111
# 4                  new reported cases of Buruli ulcer   2014    NaN        89
# 5                  new reported cases of Buruli ulcer   2013    NaN        74
# 6                  new reported cases of Buruli ulcer   2012    NaN       105
# 7                  new reported cases of Buruli ulcer   2011    NaN       143
# 8                  new reported cases of Buruli ulcer   2010    NaN        42
# 9                  new reported cases of Buruli ulcer   2009    NaN        35
# 10                 new reported cases of Buruli ulcer   2008    NaN        40
# ...

# %%
global_clean.dropna(how='all', axis="columns", inplace=True)
global_clean
# Out:
#                                    Infectious Disease   Year Angola Australia  \
# 0                  new reported cases of Buruli ulcer   2018    NaN       358
# 1                  new reported cases of Buruli ulcer   2017    NaN       292
# 2                  new reported cases of Buruli ulcer   2016    NaN       186
# 3                  new reported cases of Buruli ulcer   2015    NaN       111
# 4                  new reported cases of Buruli ulcer   2014    NaN        89
# 5                  new reported cases of Buruli ulcer   2013    NaN        74
# 6                  new reported cases of Buruli ulcer   2012    NaN       105
# 7                  new reported cases of Buruli ulcer   2011    NaN       143
# 8                  new reported cases of Buruli ulcer   2010    NaN        42
# 9                  new reported cases of Buruli ulcer   2009    NaN        35
# 10                 new reported cases of Buruli ulcer   2008    NaN        40
# ...

# %% [markdown]
# # us outbreaks

# %%
# new_customer_location_df = customer_location_df[["id", "address", "us_state"]].copy()
# new_customer_location_df.head()

outbreaks_transformed= pd. DataFrame (outbreaks_transformed
# outbreaks_transformed
# # df.reset_index()

# outbreaks_transformed = [["id", "year", "State", "Mode", "Etiology", "animal_type"]]
type(outbreaks_transformed)
# Out:
#   File "<ipython-input-291-7e1895a6c7fe>", line 9
#     type(outbreaks_transformed)
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # global outbreaks

# %%
Infect_d = pd.melt(global_clean, id_vars=["Infectious Disease", "Year"])

Infect_d

Infect_d.dropna(how='all', axis="rows", inplace=True)
Infect_d.head()
# Out:
#                     Infectious Disease   Year variable value
# 0   new reported cases of Buruli ulcer   2018   Angola   NaN
# 1   new reported cases of Buruli ulcer   2017   Angola   NaN
# 2   new reported cases of Buruli ulcer   2016   Angola   NaN
# 3   new reported cases of Buruli ulcer   2015   Angola   NaN
# 4   new reported cases of Buruli ulcer   2014   Angola   NaN

# %%
Infect_d.rename(columns={'variable':'Country', 'Infectious Disease':'Infectious_Disease'},                       
                             inplace=True)
Infect_d.head()
# Out:
#                     Infectious_Disease   Year Country value
# 0   new reported cases of Buruli ulcer   2018  Angola   NaN
# 1   new reported cases of Buruli ulcer   2017  Angola   NaN
# 2   new reported cases of Buruli ulcer   2016  Angola   NaN
# 3   new reported cases of Buruli ulcer   2015  Angola   NaN
# 4   new reported cases of Buruli ulcer   2014  Angola   NaN

# %%
Infect_d.rename(columns={'value': 'Number_cases'},
                          
                             inplace=True)
Infect_d.head()
# Out:
#                     Infectious_Disease   Year Country Number_cases
# 0   new reported cases of Buruli ulcer   2018  Angola          NaN
# 1   new reported cases of Buruli ulcer   2017  Angola          NaN
# 2   new reported cases of Buruli ulcer   2016  Angola          NaN
# 3   new reported cases of Buruli ulcer   2015  Angola          NaN
# 4   new reported cases of Buruli ulcer   2014  Angola          NaN

# %%
DF = Infect_d[["Year",  "Country", "Number_cases", "Infectious_Disease"]]
DF.head()
# Out:
#     Year Country Number_cases                   Infectious_Disease
# 0   2018  Angola          NaN   new reported cases of Buruli ulcer
# 1   2017  Angola          NaN   new reported cases of Buruli ulcer
# 2   2016  Angola          NaN   new reported cases of Buruli ulcer
# 3   2015  Angola          NaN   new reported cases of Buruli ulcer
# 4   2014  Angola          NaN   new reported cases of Buruli ulcer

# %%
#Final global outbreak table


Worldwide_Outbreaks= DF.sort_values(["Year"], ascending = True)
Worldwide_Outbreaks
# Out:
#         Year                                Country Number_cases  \
# 6595    2002                                  India          NaN
# 4487    2002                                Croatia          NaN
# 4504    2002                                   Cuba          NaN
# 4555    2002                                   Cuba          NaN
# 4572    2002                                 Cyprus          NaN
# 4623    2002                                 Cyprus          NaN
# 4640    2002                                Czechia          NaN
# 4691    2002                                Czechia          NaN
# 4708    2002  Democratic People's Republic of Korea          NaN
# 4759    2002  Democratic People's Republic of Korea          NaN
# 4776    2002                                Denmark          NaN
# 4827    2002                                Denmark          NaN
# 4844    2002                               Djibouti          NaN
# ...

# %%
Worldwide_Outbreaks.to_csv("Worldwide_Oubreaks_etl.csv")

# %%
rds_connection_string = "postgres:data@localhost:5432/Zoonotics_db"

engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['global_outbreaks', 'us_outbreaks']

# %%
outbreaks_transformed.rename(columns={"Mode": 'mode'},
                          
                             inplace=True)
outbreaks_transformed.head()
# Out:
#    year  month    state            mode                 etiology  \
# 0  2009      1     Ohio  Animal Contact  Cryptosporidium unknown
# 1  2009      3  Montana  Animal Contact  Cryptosporidium unknown
# 2  2009      4     Ohio  Animal Contact      Salmonella enterica
# 3  2009      5     Ohio  Animal Contact  Cryptosporidium unknown
# 4  2009      5     Iowa  Animal Contact  Cryptosporidium unknown
#
#       animal_type
# 0          Cattle
# 1  Sheep or goats
# 2        Pet fish
# 3          Cattle
# 4  Sheep or goats

# %%
outbreaks_transformed.insert(0, 'New_ID', range(46024, 46024 + len(outbreaks_transformed)))
outbreaks_transformed
# Out:
#      New_ID  year  month          state            mode  \
# 0     46024  2009      1           Ohio  Animal Contact
# 1     46025  2009      3        Montana  Animal Contact
# 2     46026  2009      4           Ohio  Animal Contact
# 3     46027  2009      5           Ohio  Animal Contact
# 4     46028  2009      5           Iowa  Animal Contact
# 5     46029  2009      5           Ohio  Animal Contact
# 6     46030  2009      3         Oregon  Animal Contact
# 7     46031  2009      5          Idaho  Animal Contact
# 8     46032  2009      8      Minnesota  Animal Contact
# 9     46033  2009      6       Virginia  Animal Contact
# 10    46034  2009      2        Wyoming  Animal Contact
# 11    46035  2009      8      Minnesota  Animal Contact
# 12    46036  2009      6         Oregon  Animal Contact
# 13    46037  2009      6         Oregon  Animal Contact
# 14    46038  2009      9   Pennsylvania  Animal Contact
# 15    46039  2009      1       Colorado  Animal Contact
# ...

# %% [markdown]
# # Use pandas to load csv converted DataFrame into database

# %%
outbreaks_transformed.to_sql(name='us_outbreaks', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# NotNullViolation: null value in column "id" violates not-null constraint
# DETAIL:  Failing row contains (null, 2009, 1, Ohio, Animal Contact, Cryptosporidium unknown, Cattle).
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
Worldwide_Outbreaks.to_sql(name='global_outbreaks', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# UndefinedColumn: column "Year" of relation "global_outbreaks" does not exist
# LINE 1: INSERT INTO global_outbreaks ("Year", "Country", "Number_cas...
#                                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
checking#pd.read_sql_query('select * from customer_name', con=engine).head()

# %%
pd.read_sql_query('select * from us_outbreaks', con=engine).head()
# Out:
#    New_ID     ID  year  month    state            mode  \
# 0   46024  46024  2009      1     Ohio  Animal Contact
# 1   46025  46025  2009      3  Montana  Animal Contact
# 2   46026  46026  2009      4     Ohio  Animal Contact
# 3   46027  46027  2009      5     Ohio  Animal Contact
# 4   46028  46028  2009      5     Iowa  Animal Contact
#
#                   etiology     animal_type
# 0  Cryptosporidium unknown          Cattle
# 1  Cryptosporidium unknown  Sheep or goats
# 2      Salmonella enterica        Pet fish
# 3  Cryptosporidium unknown          Cattle
# 4  Cryptosporidium unknown  Sheep or goats
