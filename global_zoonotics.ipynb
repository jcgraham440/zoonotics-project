# %%
#import dependancies
import numpy as np
import pandas as pd

# %%
burulicsv = "Resources/Global_Raw_CSV/buruli_ulcer.csv"
buruli_df = pd.read_csv(burulicsv)
buruli_df.set_index("Unnamed: 0", inplace=True)
buruli_df
# Out:
#                                  Number of new reported cases of Buruli ulcer  \
# Unnamed: 0
# Country                                                                  2018
# Angola                                                                No data
# Australia                                                                 358
# Benin                                                                     219
# Brazil                                                                No data
# Burkina Faso                                                          No data
# Cameroon                                                                  155
# Central African Republic                                              No data
# China                                                                 No data
# Congo                                                                 No data
# Côte d'Ivoire                                                             261
# ...

# %%
buruli_df=buruli_df.T

buruli_df
# Out:
# Unnamed: 0                                      Country   Angola Australia  \
# Number of new reported cases of Buruli ulcer       2018  No data       358
# Number of new reported cases of Buruli ulcer.1     2017  No data       292
# Number of new reported cases of Buruli ulcer.2     2016  No data       186
# Number of new reported cases of Buruli ulcer.3     2015  No data       111
# Number of new reported cases of Buruli ulcer.4     2014  No data        89
# Number of new reported cases of Buruli ulcer.5     2013  No data        74
# Number of new reported cases of Buruli ulcer.6     2012  No data       105
# Number of new reported cases of Buruli ulcer.7     2011  No data       143
# Number of new reported cases of Buruli ulcer.8     2010  No data        42
# Number of new reported cases of Buruli ulcer.9     2009  No data        35
# Number of new reported cases of Buruli ulcer.10    2008  No data        40
# ...

# %%
buruli_df=buruli_df.reset_index()
buruli_df["index"] = buruli_df["index"].str.replace("Number of new reported cases of", "")
buruli_df["index"] = buruli_df["index"].str.split(".", n = 1, expand = True)[0]
buruli_df
# Out:
# Unnamed: 0          index Country   Angola Australia Benin   Brazil  \
# 0            Buruli ulcer    2018  No data       358   219  No data
# 1            Buruli ulcer    2017  No data       292   267  No data
# 2            Buruli ulcer    2016  No data       186   312  No data
# 3            Buruli ulcer    2015  No data       111   311  No data
# 4            Buruli ulcer    2014  No data        89   330  No data
# 5            Buruli ulcer    2013  No data        74   378  No data
# 6            Buruli ulcer    2012  No data       105   365  No data
# 7            Buruli ulcer    2011  No data       143   492  No data
# 8            Buruli ulcer    2010  No data        42   572  No data
# 9            Buruli ulcer    2009  No data        35   674  No data
# 10           Buruli ulcer    2008  No data        40   897  No data
# 11           Buruli ulcer    2007  No data        61  1203  No data
# 12           Buruli ulcer    2006  No data        72  1195  No data
# ...

# %%
buruli_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)
buruli_df
# Out:
# Unnamed: 0 Infectious Disease   Year   Angola Australia Benin   Brazil  \
# 0                Buruli ulcer   2018  No data       358   219  No data
# 1                Buruli ulcer   2017  No data       292   267  No data
# 2                Buruli ulcer   2016  No data       186   312  No data
# 3                Buruli ulcer   2015  No data       111   311  No data
# 4                Buruli ulcer   2014  No data        89   330  No data
# 5                Buruli ulcer   2013  No data        74   378  No data
# 6                Buruli ulcer   2012  No data       105   365  No data
# 7                Buruli ulcer   2011  No data       143   492  No data
# 8                Buruli ulcer   2010  No data        42   572  No data
# 9                Buruli ulcer   2009  No data        35   674  No data
# 10               Buruli ulcer   2008  No data        40   897  No data
# 11               Buruli ulcer   2007  No data        61  1203  No data
# ...

# %%
buruli_df.rename(columns={'index':'Infectious Disease', 'Country':'Year'},inplace=True)
buruli_df
# Out:
# Unnamed: 0 Infectious Disease   Year   Angola Australia Benin   Brazil  \
# 0                Buruli ulcer   2018  No data       358   219  No data
# 1                Buruli ulcer   2017  No data       292   267  No data
# 2                Buruli ulcer   2016  No data       186   312  No data
# 3                Buruli ulcer   2015  No data       111   311  No data
# 4                Buruli ulcer   2014  No data        89   330  No data
# 5                Buruli ulcer   2013  No data        74   378  No data
# 6                Buruli ulcer   2012  No data       105   365  No data
# 7                Buruli ulcer   2011  No data       143   492  No data
# 8                Buruli ulcer   2010  No data        42   572  No data
# 9                Buruli ulcer   2009  No data        35   674  No data
# 10               Buruli ulcer   2008  No data        40   897  No data
# 11               Buruli ulcer   2007  No data        61  1203  No data
# ...

# %%
buruli_df.columns.names = ['']
buruli_df
# Out:
#    Infectious Disease   Year   Angola Australia Benin   Brazil Burkina Faso  \
# 0        Buruli ulcer   2018  No data       358   219  No data      No data
# 1        Buruli ulcer   2017  No data       292   267  No data      No data
# 2        Buruli ulcer   2016  No data       186   312  No data      No data
# 3        Buruli ulcer   2015  No data       111   311  No data      No data
# 4        Buruli ulcer   2014  No data        89   330  No data      No data
# 5        Buruli ulcer   2013  No data        74   378  No data      No data
# 6        Buruli ulcer   2012  No data       105   365  No data      No data
# 7        Buruli ulcer   2011  No data       143   492  No data      No data
# 8        Buruli ulcer   2010  No data        42   572  No data      No data
# 9        Buruli ulcer   2009  No data        35   674  No data      No data
# 10       Buruli ulcer   2008  No data        40   897  No data      No data
# ...

# %%
buruli_df_clean = buruli_df.replace("No data", "NaN")
buruli_df_clean
# Out:
#    Infectious Disease   Year Angola Australia Benin Brazil Burkina Faso  \
# 0        Buruli ulcer   2018    NaN       358   219    NaN          NaN
# 1        Buruli ulcer   2017    NaN       292   267    NaN          NaN
# 2        Buruli ulcer   2016    NaN       186   312    NaN          NaN
# 3        Buruli ulcer   2015    NaN       111   311    NaN          NaN
# 4        Buruli ulcer   2014    NaN        89   330    NaN          NaN
# 5        Buruli ulcer   2013    NaN        74   378    NaN          NaN
# 6        Buruli ulcer   2012    NaN       105   365    NaN          NaN
# 7        Buruli ulcer   2011    NaN       143   492    NaN          NaN
# 8        Buruli ulcer   2010    NaN        42   572    NaN          NaN
# 9        Buruli ulcer   2009    NaN        35   674    NaN          NaN
# 10       Buruli ulcer   2008    NaN        40   897    NaN          NaN
# 11       Buruli ulcer   2007    NaN        61  1203    NaN          NaN
# ...
